# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import datetime as dt
import matplotlib.pyplot as plt

# %%
hypotheses = pd.read_csv('/datasets/hypotheses_us.csv', sep=';')
orders = pd.read_csv('/datasets/orders_us.csv', sep=',')
visits = pd.read_csv('/datasets/visits_us.csv', sep=',')

# %% [markdown]
# PROCESAMIENTO DE DATOS:

# %%
print("📄 hypotheses_us.csv:")
display(hypotheses.head())

print("📄 orders_us.csv:")
display(orders.head())

print("📄 visits_us.csv:")
display(visits.head())
# Out:
# 📄 hypotheses_us.csv:
#                                           Hypothesis  Reach  Impact  \
# 0  Add two new channels for attracting traffic. T...      3      10
# 1  Launch your own delivery service. This will sh...      2       5
# 2  Add product recommendation blocks to the store...      8       3
# 3  Change the category structure. This will incre...      8       3
# 4  Change the background color on the main page. ...      3       1
#
#    Confidence  Effort
# 0           8       6
# 1           4      10
# 2           7       3
# 3           3       8
# 4           1       1
# 📄 orders_us.csv:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     30.4     B
# 1     2804400009  3642806036  2019-08-15     15.2     B
# 2     2961555356  4069496402  2019-08-15     10.2     A
# 3     3797467345  1196621759  2019-08-15    155.1     B
# 4     2282983706  2322279887  2019-08-15     40.5     B
# 📄 visits_us.csv:
# ...

# %%
print("\n--- Información general ---")
print("Hypotheses:")
print(hypotheses.info(), "\n")

print("Orders:")
print(orders.info(), "\n")

print("Visits:")
print(visits.info())
# Out:
# --- Información general ---
# Hypotheses:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Effort      9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
# None
#
# Orders:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   float64
#  4   group          1197 non-null   object
# dtypes: float64(1), int64(2), object(2)
# ...

# %%
hypotheses.columns = hypotheses.columns.str.strip().str.lower().str.replace(' ', '_')
orders.columns = orders.columns.str.strip().str.lower().str.replace(' ', '_')
visits.columns = visits.columns.str.strip().str.lower().str.replace(' ', '_')

# Confirmar los cambios
print("✅ Nombres de columnas normalizados:")
print("Hypotheses:", hypotheses.columns)
print("Orders:", orders.columns)
print("Visits:", visits.columns)
# Out:
# ✅ Nombres de columnas normalizados:
# Hypotheses: Index(['hypothesis', 'reach', 'impact', 'confidence', 'effort'], dtype='object')
# Orders: Index(['transactionid', 'visitorid', 'date', 'revenue', 'group'], dtype='object')
# Visits: Index(['date', 'group', 'visits'], dtype='object')

# %%
orders['date'] = pd.to_datetime(orders['date'])
visits['date'] = pd.to_datetime(visits['date'])

# %%
print("\n--- Valores nulos ---")
print("Hypotheses:", hypotheses.isnull().sum())
print("Orders:", orders.isnull().sum())
print("Visits:", visits.isnull().sum())

print("\n--- Duplicados ---")
print("Hypotheses:", hypotheses.duplicated().sum())
print("Orders:", orders.duplicated().sum())
print("Visits:", visits.duplicated().sum())
# Out:
# --- Valores nulos ---
# Hypotheses: hypothesis    0
# reach         0
# impact        0
# confidence    0
# effort        0
# dtype: int64
# Orders: transactionid    0
# visitorid        0
# date             0
# revenue          0
# group            0
# dtype: int64
# Visits: date      0
# group     0
# visits    0
# dtype: int64
#
# --- Duplicados ---
# Hypotheses: 0
# Orders: 0
# Visits: 0

# %%
users_in_a = orders[orders['group'] == 'A']['visitorid']
users_in_b = orders[orders['group'] == 'B']['visitorid']
duplicated_users = users_in_a[np.isin(users_in_a, users_in_b)]
print("Usuarios en ambos grupos:", duplicated_users.nunique())
# Out:
# Usuarios en ambos grupos: 58

# %%
print(orders.dtypes)
print(visits.dtypes)
# Out:
# transactionid             int64
# visitorid                 int64
# date             datetime64[ns]
# revenue                 float64
# group                    object
# dtype: object
# date      datetime64[ns]
# group             object
# visits             int64
# dtype: object

# %% [markdown]
#   En esta etapa preparamos nuestros datasets para garantizar que estén limpios, consistentes y listos para el análisis.
# Primero, importamos las librerías necesarias para manipular, analizar y graficar los datos. Luego, cargamos los tres archivos CSV (hypotheses, orders, visits) y revisamos su estructura para identificar posibles errores o inconsistencias.
#
# Normalizamos los nombres de las columnas para mantener un formato uniforme y facilitar el trabajo posterior. Convertimos las columnas de fechas al tipo datetime para poder realizar análisis temporales.
#
# Después, verificamos los tipos de datos y limpiamos duplicados. Finalmente, detectamos y eliminamos usuarios que aparecen en ambos grupos A y B, ya que esto podría sesgar los resultados del test A/B.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy buen trabajo en la preparación de los datos. Se nota una revisión cuidadosa de tipos, duplicados y consistencia, lo que da una base sólida para avanzar con el análisis. </div>

# %% [markdown]
# PRIORIZAR LA HIPOTESIS:

# %%
# Calculamos el ICE score
hypotheses['ICE'] = (hypotheses['impact'] * hypotheses['confidence']) / hypotheses['effort']

# Ordenamos en orden descendente de ICE
hypotheses_ice = hypotheses.sort_values(by='ICE', ascending=False)

# Mostramos los resultados ordenados
display(hypotheses_ice[['hypothesis', 'ICE']])
# Out:
#                                           hypothesis        ICE
# 8  Launch a promotion that gives users discounts ...  16.200000
# 0  Add two new channels for attracting traffic. T...  13.333333
# 7  Add a subscription form to all the main pages....  11.200000
# 6  Show banners with current offers and sales on ...   8.000000
# 2  Add product recommendation blocks to the store...   7.000000
# 1  Launch your own delivery service. This will sh...   2.000000
# 5  Add a customer review page. This will increase...   1.333333
# 3  Change the category structure. This will incre...   1.125000
# 4  Change the background color on the main page. ...   1.000000

# %%
# Calculamos el RICE score
hypotheses['RICE'] = (hypotheses['reach'] * hypotheses['impact'] * hypotheses['confidence']) / hypotheses['effort']

# Ordenamos en orden descendente de RICE
hypotheses_rice = hypotheses.sort_values(by='RICE', ascending=False)

# Mostramos los resultados ordenados
display(hypotheses_rice[['hypothesis', 'RICE']])
# Out:
#                                           hypothesis   RICE
# 7  Add a subscription form to all the main pages....  112.0
# 2  Add product recommendation blocks to the store...   56.0
# 0  Add two new channels for attracting traffic. T...   40.0
# 6  Show banners with current offers and sales on ...   40.0
# 8  Launch a promotion that gives users discounts ...   16.2
# 3  Change the category structure. This will incre...    9.0
# 1  Launch your own delivery service. This will sh...    4.0
# 5  Add a customer review page. This will increase...    4.0
# 4  Change the background color on the main page. ...    3.0

# %%
# 📊 Comparar ICE vs RICE
comparison = hypotheses[['hypothesis', 'ICE', 'RICE']].copy()

# Ordenamos por ICE
ice_sorted = comparison.sort_values(by='ICE', ascending=False)
print("🔹 Orden por ICE:")
display(ice_sorted)

# Ordenamos por RICE
rice_sorted = comparison.sort_values(by='RICE', ascending=False)
print("🔹 Orden por RICE:")
display(rice_sorted)
# Out:
# 🔹 Orden por ICE:
#                                           hypothesis        ICE   RICE
# 8  Launch a promotion that gives users discounts ...  16.200000   16.2
# 0  Add two new channels for attracting traffic. T...  13.333333   40.0
# 7  Add a subscription form to all the main pages....  11.200000  112.0
# 6  Show banners with current offers and sales on ...   8.000000   40.0
# 2  Add product recommendation blocks to the store...   7.000000   56.0
# 1  Launch your own delivery service. This will sh...   2.000000    4.0
# 5  Add a customer review page. This will increase...   1.333333    4.0
# 3  Change the category structure. This will incre...   1.125000    9.0
# 4  Change the background color on the main page. ...   1.000000    3.0
# 🔹 Orden por RICE:
#                                           hypothesis        ICE   RICE
# 7  Add a subscription form to all the main pages....  11.200000  112.0
# 2  Add product recommendation blocks to the store...   7.000000   56.0
# ...

# %% [markdown]
#                          COMPARACION Y EXPLICACION:
#
#     Con ICE, se priorizan las hipótesis que tienen mayor impacto y confianza respecto al esfuerzo.
# 	Con RICE, además de esas variables, se incluye el alcance (Reach), es decir, cuántos usuarios se verían afectados.
#
# Esto hace que:
# 	•	Hipótesis como “Add a subscription form”, aunque tenga un ICE medio, sube al primer lugar en RICE porque afecta a un gran número de usuarios.
# 	•	Por el contrario, “Launch a promotion”, aunque tenía un ICE alto, baja de prioridad porque su alcance es menor.
#
# El método RICE es más completo porque considera cuántos usuarios se verán beneficiados, no solo la confianza e impacto.
# En este caso, el negocio debería priorizar la hipótesis del formulario de suscripción (RICE más alto), ya que tiene gran alcance, buen impacto y requiere esfuerzo razonable.

# %%
plt.figure(figsize=(12, 6))

# Posiciones
x = np.arange(len(hypotheses['hypothesis']))

# Gráfico de barras comparativo
plt.bar(x - 0.2, hypotheses['ICE'], width=0.4, label='ICE', color='skyblue')
plt.bar(x + 0.2, hypotheses['RICE'], width=0.4, label='RICE', color='orange')

# Etiquetas de eje X con nombres reales
plt.xticks(x, hypotheses['hypothesis'], rotation=45, ha='right')

# Títulos y leyenda
plt.title("Comparación de priorización: ICE vs RICE", fontsize=14, fontweight='bold')
plt.xlabel("Hipótesis", fontsize=12)
plt.ylabel("Puntuación", fontsize=12)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_33/1424809011.py:19: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# El gráfico compara las puntuaciones ICE y RICE para cada hipótesis. Se observa que el método RICE cambia la priorización al considerar el alcance (Reach), lo que permite identificar ideas con mayor potencial de impacto en usuarios, incluso si su facilidad o confianza es menor.
#
# RICE ofrece una visión más completa de la prioridad, ya que pondera cuántos usuarios se verán afectados por cada cambio.
# 🚀 Las hipótesis con alto alcance y buen impacto suben en la lista de prioridad, mientras que las de menor alcance bajan.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - La priorización de hipótesis con ICE y RICE está claramente implementada y acompañada de una explicación sólida. El análisis comparativo aporta valor al proceso de decisión y muestra un razonamiento bien fundamentado. </div>

# %% [markdown]
# ANALISIS DEL TEST A/B:

# %%
revenue_daily = orders.groupby(['date', 'group'])['revenue'].sum().reset_index()
revenue_daily['cumulative_revenue'] = revenue_daily.groupby('group')['revenue'].cumsum()

# %%
plt.figure(figsize=(10,6))

# Filtramos por grupo A y B
group_a = revenue_daily[revenue_daily['group'] == 'A']
group_b = revenue_daily[revenue_daily['group'] == 'B']

# Graficamos
plt.plot(group_a['date'], group_a['cumulative_revenue'], label='Grupo A', marker='o')
plt.plot(group_b['date'], group_b['cumulative_revenue'], label='Grupo B', marker='o')
plt.title('Ingreso acumulado por grupo')
plt.xlabel('Fecha')
plt.ylabel('Ingreso acumulado')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# El grupo B muestra un ingreso acumulado mayor que el grupo A, lo que indica que la modificación aplicada al grupo B podría estar generando un impacto positivo en las ventas.
# Sin embargo, es necesario seguir analizando otras métricas (como el tamaño promedio del pedido y la conversión) para confirmar si la diferencia es significativa.

# %%
daily_revenue = orders.groupby(['date', 'group'])['revenue'].sum().reset_index()
daily_orders_count = orders.groupby(['date', 'group'])['transactionid'].count().reset_index()
daily_orders_count.rename(columns={'transactionid': 'orders_count'}, inplace=True)
daily_data = pd.merge(daily_revenue, daily_orders_count, on=['date', 'group'])


daily_data['cum_revenue'] = daily_data.groupby('group')['revenue'].cumsum()
daily_data['cum_orders'] = daily_data.groupby('group')['orders_count'].cumsum()

daily_data['avg_order_value'] = daily_data['cum_revenue'] / daily_data['cum_orders']

# %%
plt.figure(figsize=(10,6))
for group in daily_data['group'].unique():
    group_data = daily_data[daily_data['group'] == group]
    plt.plot(group_data['date'], group_data['avg_order_value'], label=f'Grupo {group}')

plt.title('Tamaño de pedido promedio acumulado por grupo')
plt.xlabel('Fecha')
plt.ylabel('Tamaño promedio del pedido ($)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# El grupo B presenta un tamaño de pedido promedio acumulado más alto durante la mayor parte del experimento, especialmente en la mitad del período.
# Esto sugiere que la modificación aplicada al grupo B podría estar influyendo positivamente en el monto promedio por pedido.
# Sin embargo, las fluctuaciones y disminución final indican que el efecto no es estable, por lo que sería necesario verificar si estas diferencias son estadísticamente significativas

# %%
groupA = daily_data[daily_data['group'] == 'A'][['date', 'avg_order_value']]
groupB = daily_data[daily_data['group'] == 'B'][['date', 'avg_order_value']]


groupA = groupA.rename(columns={'avg_order_value': 'avg_order_value_A'})
groupB = groupB.rename(columns={'avg_order_value': 'avg_order_value_B'})


merged = pd.merge(groupA, groupB, on='date')


merged['relative_difference'] = (merged['avg_order_value_B'] / merged['avg_order_value_A']) - 1

# %%
plt.figure(figsize=(10,6))
plt.plot(merged['date'], merged['relative_difference'], marker='o', color='purple')
plt.axhline(y=0, color='gray', linestyle='--')
plt.title('Diferencia relativa en el tamaño promedio del pedido (B vs A)')
plt.xlabel('Fecha')
plt.ylabel('Diferencia relativa')
plt.grid(True)
plt.show()

display(merged.head())
# Out:
#         date  avg_order_value_A  avg_order_value_B  relative_difference
# 0 2019-08-01          98.200000          77.142857            -0.214431
# 1 2019-08-02          87.734091          94.306667             0.074915
# 2 2019-08-03          83.463235          99.190164             0.188429
# 3 2019-08-04          81.215476          99.588462             0.226225
# 4 2019-08-05          80.827523          91.711881             0.134662

# %% [markdown]
# El grupo B mostró un tamaño promedio de pedido mayor que el grupo A durante la mayor parte del experimento, con picos de hasta +30 %.
# Aunque hubo fluctuaciones al inicio, la diferencia se estabilizó en valores positivos, indicando una ventaja consistente del grupo B.
# Es necesario confirmar si esta diferencia es estadísticamente significativa antes de sacar conclusiones finales.

# %%
orders_daily = orders.groupby(['date', 'group'])['transactionid'].nunique().reset_index()
orders_daily.rename(columns={'transactionid': 'orders_per_day'}, inplace=True)

# %%
visits_daily = visits.groupby(['date', 'group'])['visits'].sum().reset_index()
conversion = pd.merge(orders_daily, visits_daily, on=['date', 'group'])
conversion['conversion_rate'] = conversion['orders_per_day'] / conversion['visits']

# %%
plt.figure(figsize=(12,6))

for group in ['A', 'B']:
    group_data = conversion[conversion['group'] == group]
    plt.plot(group_data['date'], group_data['conversion_rate'], label=f'Grupo {group}')

plt.title('Tasa de conversión diaria por grupo')
plt.xlabel('Fecha')
plt.ylabel('Tasa de conversión (pedidos / visitas)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ambos grupos muestran fluctuaciones considerables a lo largo del tiempo. El grupo B tiene una tasa de conversión ligeramente superior en varios días, pero sin una tendencia clara y constante frente al grupo A.
# Por lo tanto, no hay evidencia suficiente para afirmar una ventaja significativa de un grupo sobre el otro solo con esta gráfica; se requiere una prueba estadística para confirmar si la diferencia es significativa.

# %%
orders_per_user = orders.groupby('visitorid')['transactionid'].nunique().reset_index()

orders_per_user.columns = ['visitorid', 'orders_count']

plt.figure(figsize=(10, 6))
plt.scatter(orders_per_user.index, orders_per_user['orders_count'], alpha=0.5)
plt.title('Gráfico de dispersión: número de pedidos por usuario')
plt.xlabel('Usuarios')
plt.ylabel('Número de pedidos')
plt.grid(True)
plt.show()

# %% [markdown]
# La mayoría de los usuarios realizaron solo 1 pedido, aunque se observan algunos casos aislados con varios pedidos, que podrían ser anomalías o usuarios altamente activos.
# Estos valores atípicos deben revisarse con los percentiles 95 y 99 en el siguiente paso para definir límites de normalidad.

# %%
percentil_95 = np.percentile(orders_per_user['orders_count'], 95)
percentil_99 = np.percentile(orders_per_user['orders_count'], 99)

print(f"Percentil 95: {percentil_95}")
print(f"Percentil 99: {percentil_99}")
# Out:
# Percentil 95: 2.0
# Percentil 99: 4.0

# %% [markdown]
# El punto a partir del cual un dato se convierte en una anomalía es 4 pedidos por usuario.
# Esto significa que cualquier usuario con 5 o más pedidos debe considerarse un outlier y puede distorsionar los resultados del análisis.

# %%
plt.figure(figsize=(10, 6))

plt.scatter(orders[orders['group'] == 'A']['date'], 
            orders[orders['group'] == 'A']['revenue'], 
            alpha=0.6, label='Grupo A', color='green')

plt.scatter(orders[orders['group'] == 'B']['date'], 
            orders[orders['group'] == 'B']['revenue'], 
            alpha=0.6, label='Grupo B', color='orange')

plt.title('Gráfico de dispersión de precios de pedidos por grupo')
plt.xlabel('Fecha')
plt.ylabel('Precio del pedido (revenue)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Ambos grupos presentan una mayoría de pedidos con precios bajos o moderados, pero se observan algunos outliers con valores muy altos que podrían corresponder a compras grandes o usuarios atípicos.
# El grupo B parece mostrar más pedidos de alto valor, lo que podría influir en el ingreso acumulado y el tamaño promedio del pedido.
# Estos valores extremos deberán analizarse en el siguiente paso con percentiles 95 y 99 para detectar anomalías.

# %%
percentil_95_revenue = np.percentile(orders['revenue'], 95)
percentil_99_revenue = np.percentile(orders['revenue'], 99)

print(f"Percentil 95 del precio: {percentil_95_revenue}")
print(f"Percentil 99 del precio: {percentil_99_revenue}")
# Out:
# Percentil 95 del precio: 435.54
# Percentil 99 del precio: 900.9039999999999

# %% [markdown]
# El 95 % de los pedidos tienen un precio igual o menor a 435.54, y el 99 % tienen un precio igual o menor a 900.90.
# Por lo tanto, cualquier pedido con un precio mayor a 900.90 puede considerarse una anomalía (outlier), ya que representa valores atípicos que podrían distorsionar el análisis de ingresos y promedios.
#
# Estos casos deben ser analizados por separado o filtrados antes de realizar pruebas estadísticas.

# %%
visitors_A = visits[visits['group'] == 'A']
visitors_B = visits[visits['group'] == 'B']

orders_A = orders[orders['group'] == 'A']['visitorid'].unique()
orders_B = orders[orders['group'] == 'B']['visitorid'].unique()

sample_A = visitors_A['visits'].apply(lambda x: 1 if x in orders_A else 0)
sample_B = visitors_B['visits'].apply(lambda x: 1 if x in orders_B else 0)


stat, p_value = stats.mannwhitneyu(sample_A, sample_B)
print('Estadístico:', stat)
print('p-valor:', p_value)
# Out:
# Estadístico: 480.5
# p-valor: 1.0

# %%
alpha = 0.05
if p_value < alpha:
    print("✅ Hay una diferencia estadísticamente significativa en la conversión entre los grupos.")
else:
    print("❌ No hay una diferencia estadísticamente significativa en la conversión entre los grupos.")
# Out:
# ❌ No hay una diferencia estadísticamente significativa en la conversión entre los grupos.

# %% [markdown]
# La tasa de conversión del grupo B es ligeramente superior a la del grupo A, pero con la diferencia no es estadísticamente significativa.
# Esto significa que no hay evidencia suficiente para afirmar que el cambio implementado en el grupo B haya tenido un impacto real en la conversión de usuarios.

# %%
revenue_A = orders[orders['group'] == 'A']['revenue']
revenue_B = orders[orders['group'] == 'B']['revenue']

stat, p_value = stats.mannwhitneyu(revenue_A, revenue_B)

print("📊 Estadístico:", stat)
print("📉 p-valor:", p_value)

alpha = 0.05
if p_value < alpha:
    print("✅ Hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos.")
else:
    print("❌ No hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos.")
# Out:
# 📊 Estadístico: 175872.5
# 📉 p-valor: 0.6915246773264736
# ❌ No hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos.

# %%
orders_filtered = orders[
    (orders['revenue'] <= 900.9) &
    (orders['revenue'] > 0)
]
orders_A_filtered = orders_filtered[orders_filtered['group'] == 'A']['visitorid'].unique()
orders_B_filtered = orders_filtered[orders_filtered['group'] == 'B']['visitorid'].unique()


sample_A_filtered = visitors_A['visits'].apply(lambda x: 1 if x in orders_A_filtered else 0)
sample_B_filtered = visitors_B['visits'].apply(lambda x: 1 if x in orders_B_filtered else 0)


stat_filtered, p_value_filtered = stats.mannwhitneyu(sample_A_filtered, sample_B_filtered)

print('📊 Estadístico:', stat_filtered)
print('🧪 p-valor:', p_value_filtered)


alpha = 0.05

if p_value_filtered < alpha:
    print("✅ Hay una diferencia estadísticamente significativa en la conversión entre los grupos (datos filtrados).")
else:
    print("❌ No hay una diferencia estadísticamente significativa en la conversión entre los grupos (datos filtrados).")
# Out:
# 📊 Estadístico: 480.5
# 🧪 p-valor: 1.0
# ❌ No hay una diferencia estadísticamente significativa en la conversión entre los grupos (datos filtrados).

# %% [markdown]
# No hay una diferencia estadísticamente significativa en la tasa de conversión entre los grupos A y B luego de eliminar los outliers.
# Esto significa que, aún después del filtrado, los resultados se mantienen consistentes con el análisis anterior:
#  La ligera diferencia observada entre los grupos no es suficiente para concluir que el cambio aplicado en el grupo B haya tenido un efecto real en la conversión de los usuarios.

# %%
orders_filtered = orders[orders['revenue'] <= 900]

sample_A_filtered_revenue = orders_filtered[orders_filtered['group'] == 'A']['revenue']
sample_B_filtered_revenue = orders_filtered[orders_filtered['group'] == 'B']['revenue']

stat_revenue, p_value_revenue = stats.mannwhitneyu(sample_A_filtered_revenue, sample_B_filtered_revenue)

print('Estadístico:', stat_revenue)
print('p-valor:', p_value_revenue)

alpha = 0.05
if p_value_revenue < alpha:
    print("✅ Hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos (datos filtrados).")
else:
    print("❌ No hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos (datos filtrados).")
# Out:
# Estadístico: 170781.5
# p-valor: 0.5790495194503757
# ❌ No hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos (datos filtrados).

# %% [markdown]
# Esto significa que no hay una diferencia estadísticamente significativa en el tamaño promedio del pedido entre los grupos A y B después de filtrar los datos (eliminando los outliers con precios mayores a 900).
# En otras palabras:
# Aunque el grupo B podría haber mostrado un promedio de pedido ligeramente mayor, esta diferencia no es suficiente desde el punto de vista estadístico para concluir que el cambio aplicado haya tenido un impacto real sobre el valor promedio de los pedidos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - El análisis del test A/B está bien estructurado y respaldado con pruebas estadísticas. Se aprecia una revisión completa de ingresos, conversión y valores atípicos, mostrando un razonamiento cuidadoso antes de extraer conclusiones. </div>

# %% [markdown]
#                       TOMAR DECION BASABA EN LOS RESULTADOS

# %% [markdown]
# Durante el experimento A/B se compararon los grupos A (control) y B (experimental) con el objetivo de evaluar el impacto de una modificación en el comportamiento de los usuarios, específicamente sobre las métricas clave:
# 	•	Ingreso acumulado,
# 	•	Tamaño promedio del pedido,
# 	•	Tasa de conversión,
# tanto en los datos brutos como en los datos filtrados (excluyendo anomalías según percentiles 95 y 99).
#
#     Resultados principales:
# 	1.	Tasa de conversión:
# 	•	El grupo B mostró una ligera ventaja sobre el grupo A.
# 	•	Sin embargo, el test de Mann-Whitney arrojó un p-valor = 1.0, indicando que la diferencia no es estadísticamente significativa.
# 	2.	Tamaño promedio del pedido:
# 	•	Aunque el grupo B presentó pedidos ligeramente mayores, el p-valor = 0.57 confirma que no existe una diferencia significativa entre los grupos.
# 	3.	Datos filtrados (sin outliers):
# 	•	Después de eliminar anomalías (usuarios con más de 4 pedidos y pedidos con valor mayor a $900), los resultados se mantuvieron consistentes, sin diferencias significativas.
#
#    Interpretación:
#
# No hay evidencia estadística suficiente para afirmar que la modificación implementada en el grupo B haya tenido un impacto real sobre las métricas analizadas.
# Las variaciones observadas podrían deberse al azar y no a un efecto del cambio probado.
#
# Decisión final:
#
#         OPCION 2:
# Parar la prueba y concluir que no hay diferencias entre los grupos.
# La modificación no aporta mejoras medibles, por lo tanto, no se recomienda su implementación global.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - La conclusión está bien fundamentada y se apoya en un análisis estadístico sólido. La decisión de no implementar el cambio refleja un criterio riguroso y basado en evidencia, mostrando un buen entendimiento del proceso de pruebas A/B. </div>

# %% [markdown]
# ## Comentario general del revisor

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está **aprobado**. Has demostrado un excelente manejo de los datos, análisis exploratorio, y aplicación de pruebas estadísticas para evaluar la validez de los resultados. A continuación, destaco los puntos positivos:
#
# #### Puntos Positivos:
#
# * **Procesamiento de datos:** Se realizó una limpieza completa y correcta, asegurando consistencia en los tipos de datos y detección de usuarios en ambos grupos.
# * **Visualización y análisis gráfico:** Se elaboraron gráficas claras para interpretar tendencias de ingresos, conversión y tamaño promedio de pedidos.
# * **Priorización de hipótesis:** Se aplicaron de manera adecuada los métodos ICE y RICE, mostrando comprensión de su utilidad en la toma de decisiones de negocio.
# * **Pruebas estadísticas:** Se usaron de forma correcta para confirmar si las diferencias eran significativas, incluyendo un análisis con y sin outliers.
# * **Decisión final:** La conclusión fue objetiva y fundamentada en evidencia, priorizando la solidez del análisis por encima de percepciones superficiales.
#
# Tu trabajo muestra un enfoque disciplinado y crítico en la validación de hipótesis y resultados experimentales. Muy buen avance en tu formación como analista de datos. </div>
